# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")
sns.set(style="whitegrid")

# %%
df = pd.read_csv("D:\Fraud detection\AIML Dataset.csv")

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            str
#  2   amount          float64
#  3   nameOrig        str
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        str
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), str(3)
# memory usage: 534.0 MB

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
df["isFraud"].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df["isFlaggedFraud"].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (6362620, 11)

# %%
(df["isFraud"].value_counts()[1] / df.shape[0])*100
# Out:
# np.float64(0.12908204481801522)

# %%
round((df["isFraud"].value_counts()[1] / df.shape[0])*100,2)
# Out:
# np.float64(0.13)

# %%
df["type"].value_counts().plot(kind="bar",title="Transaction Types",color="skyblue")
plt.xlabel("Transaction Type")
plt.ylabel("Count")
plt.show()

# %%
fraud_by_types = df.groupby("type")["isFraud"].mean().sort_values(ascending=False)
fraud_by_types.plot(kind="bar", title="Fraud rate by type", color = "salmon")
plt.ylabel("Fraud Rate")
plt.show()

# %%
df["amount"].describe().astype(int)
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int64

# %%
sns.histplot(np.log1p(df["amount"]), bins=100, kde=True, color="green")
plt.title("Transaction amount distribution (Log scale)")
plt.xlabel("Log(Amount+1)")
plt.show()

# %%
sns.boxplot(data=df[df["amount"] < 50000], x = "isFraud", y="amount")
plt.title("Amount vs isFraud (For less than 50k)")
plt.show()

# %% [markdown]
# For amount less than 50k, we have higher fraud rate on more amount (mean is high) compared to no fraud where the mean is on the lower side

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
df["balanceDiffOrg"] = df["oldbalanceOrg"] - df["newbalanceOrig"]
df["balanceDiffDest"] = df["newbalanceDest"] - df["oldbalanceDest"]

# %%
(df["balanceDiffOrg"] < 0).sum()
# Out:
# np.int64(1399253)

# %%
(df["balanceDiffDest"] < 0).sum()
# Out:
# np.int64(1238864)

# %%
frauds_per_step = df[df["isFraud"] == 1]["step"].value_counts().sort_index()
plt.plot(frauds_per_step.index, frauds_per_step.values, label="Frauds per step")
plt.xlabel("Step (time)")
plt.ylabel("Number of Frauds")
plt.title("Frauds over time")
plt.grid(True)
plt.show()

# %% [markdown]
# This shows that Frauds are not time dependent

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balanceDiffOrg  balanceDiffDest
# 0         9839.64              0.0
# ...

# %%
top_senders = df["nameOrig"].value_counts().head(10)

# %%
top_senders
# Out:
# nameOrig
# C2098525306    3
# C400299098     3
# C1999539787    3
# C1065307291    3
# C545315117     3
# C1976208114    3
# C1784010646    3
# C1530544995    3
# C1902386530    3
# C1677795071    3
# Name: count, dtype: int64

# %%
top_receivers = df["nameDest"].value_counts().head(10)

# %%
top_receivers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C451111351      99
# C1789550256     99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraud_users = df[df["isFraud"]==1]["nameOrig"].value_counts().head(10)

# %%
fraud_users
# Out:
# nameOrig
# C1305486145    1
# C840083671     1
# C1420196421    1
# C2101527076    1
# C137533655     1
# C1118430673    1
# C749981943     1
# C1334405552    1
# C467632528     1
# C1364127192    1
# Name: count, dtype: int64

# %%
fraud_types = df[df["type"].isin(["TRANSFER","CASH_OUT"])]

# %%
fraud_types
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 15          1  CASH_OUT   229133.94   C905080434       15325.00
# 19          1  TRANSFER   215310.30  C1670993182         705.00
# 24          1  TRANSFER   311685.89  C1984094095       10835.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 2                   0.0   C553264065            0.00            0.00        1
# ...

# %%
fraud_types["type"].value_counts()
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
sns.countplot(data=fraud_types,x="type",hue="isFraud")
plt.title("Fraud Distribution in Transfer and Cash out")
plt.show()

# %%
corr = df[["amount","oldbalanceOrg","newbalanceOrig","oldbalanceDest","newbalanceDest","isFraud"]].corr()

# %%
corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
# isFraud         0.076688       0.010154       -0.008148       -0.005885
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# newbalanceOrig        0.041837 -0.008148
# oldbalanceDest        0.976569 -0.005885
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %%
sns.heatmap(corr,annot=True,cmap="coolwarm",fmt=" .2f")
# Out:
# <Axes: >

# %% [markdown]
# Filtering the customers whose account balance goes to zero after the transfer

# %%
zero_after_transfer = df[
    (df["oldbalanceOrg"]>0) &
    (df["newbalanceOrig"] == 0) &
    (df["type"].isin(["TRANSFER","CASH_OUT"]))
]

# %%
zero_after_transfer
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 15          1  CASH_OUT   229133.94   C905080434       15325.00
# 19          1  TRANSFER   215310.30  C1670993182         705.00
# 24          1  TRANSFER   311685.89  C1984094095       10835.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 2                   0.0   C553264065            0.00            0.00        1
# ...

# %%
len(zero_after_transfer)
# Out:
# 1188074

# %%
df["isFraud"].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %% [markdown]
# Feature Selection and Preparation

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
df.drop(columns="step",inplace=True)

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balanceDiffOrg  balanceDiffDest
# 0         9839.64              0.0
# 1         1864.28              0.0
# ...

# %%
df_model = df.drop(["nameOrig","nameDest","isFlaggedFraud"],axis=1)

# %%
df_model.head()
# Out:
#        type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2  TRANSFER    181.00          181.0            0.00             0.0
# 3  CASH_OUT    181.00          181.0            0.00         21182.0
# 4   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud  balanceDiffOrg  balanceDiffDest
# 0             0.0        0         9839.64              0.0
# 1             0.0        0         1864.28              0.0
# 2             0.0        1          181.00              0.0
# 3             0.0        1          181.00         -21182.0
# 4             0.0        0        11668.14              0.0

# %%
categorical =  ["type"]
numeric = ["amount","oldbalanceOrg","newbalanceOrig","oldbalanceDest","newbalanceDest"]

# %%
y = df_model["isFraud"]
X = df_model.drop("isFraud",axis =1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, stratify=y)

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ("num", StandardScaler(), numeric),
            ("cat", OneHotEncoder(drop="first"), categorical)  
             ],
             remainder="drop"
)

# %%
pipeline = Pipeline([
    ("prep", preprocessor),
    ("clf",LogisticRegression(class_weight="balanced", max_iter=1000))
])

# %% [markdown]
# We are using class_weight as balanced as 99% of our data is not fraud, so model will predict not fraud if we dont balance the class weight

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred = pipeline.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97   1906322
#            1       0.02      0.94      0.04      2464
#
#     accuracy                           0.95   1908786
#    macro avg       0.51      0.94      0.51   1908786
# weighted avg       1.00      0.95      0.97   1908786

# %% [markdown]
# The precision is very less, so we will try out some other models too

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1801594,  104728],
#        [    139,    2325]])

# %%
pipeline.score(X_test,y_test)
# Out:
# 0.9450608921062916

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import (precision_score, recall_score, f1_score, roc_auc_score, average_precision_score, confusion_matrix)

# %%
pipeline_rf = Pipeline([
    ("prep", preprocessor),
    ("clf", RandomForestClassifier(
        n_estimators=300,
        max_depth=10,
        class_weight="balanced",
        random_state=42,
        n_jobs=-1
    ))
])

# %%
pipeline_rf.fit(X_train,y_train)

y_pred_rf = pipeline_rf.predict(X_test)

print(classification_report(y_test,y_pred_rf))
print(confusion_matrix(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99   1906322
#            1       0.08      1.00      0.15      2464
#
#     accuracy                           0.99   1908786
#    macro avg       0.54      0.99      0.57   1908786
# weighted avg       1.00      0.99      0.99   1908786
#
# [[1878713   27609]
#  [     12    2452]]

# %%
from xgboost import XGBClassifier

ratio = (y_train==0).sum()/(y_train==1).sum()

pipeline_xgb = Pipeline([
    ("prep", preprocessor),
    ("clf", XGBClassifier(
        n_estimators=300,
        max_depth=6,
        learning_rate=0.05,
        scale_pos_weight=ratio,
        random_state=42,
        eval_metric="logloss"
    ))
])

pipeline_xgb.fit(X_train,y_train)

y_pred_xgb = pipeline_xgb.predict(X_test)

print(classification_report(y_test,y_pred_xgb))
print(confusion_matrix(y_test,y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   1906322
#            1       0.26      1.00      0.41      2464
#
#     accuracy                           1.00   1908786
#    macro avg       0.63      1.00      0.70   1908786
# weighted avg       1.00      1.00      1.00   1908786
#
# [[1899249    7073]
#  [      7    2457]]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

results = pd.DataFrame({
    "Model":[
        "Logistic",
        "RandomForest",
        "XGBoost",
    ],
    "Precision":[
        precision_score(y_test,y_pred),
        precision_score(y_test,y_pred_rf),
        precision_score(y_test,y_pred_xgb),
    ],
    "Recall":[
        recall_score(y_test,y_pred),
        recall_score(y_test,y_pred_rf),
        recall_score(y_test,y_pred_xgb),
    ],
    "F1":[
        f1_score(y_test,y_pred),
        f1_score(y_test,y_pred_rf),
        f1_score(y_test,y_pred_xgb),
    ]
})

print(results.sort_values("F1",ascending=False))
# Out:
#           Model  Precision    Recall        F1
# 2       XGBoost   0.257817  0.997159  0.409705
# 1  RandomForest   0.081567  0.995130  0.150776
# 0      Logistic   0.021718  0.943588  0.042459

# %%
from sklearn.metrics import roc_auc_score, average_precision_score

y_prob = pipeline_xgb.predict_proba(X_test)[:,1]

print("ROC-AUC:", roc_auc_score(y_test,y_prob))
print("PR-AUC :", average_precision_score(y_test,y_prob))
# Out:
# ROC-AUC: 0.9997729157518762
# PR-AUC : 0.9376834835273529

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt

plot_importance(
    pipeline_xgb.named_steps["clf"],
    max_num_features=15
)

plt.show()

# %%
import joblib
joblib.dump(pipeline_xgb,"fraud_detection_pipieline.pkl")
# Out:
# ['fraud_detection_pipieline.pkl']
